# %% [markdown]
# <a href="https://colab.research.google.com/github/qaadhare-tip/CPE-018-CPE31S2---Emerging-Technologies-1-in-CpE/blob/main/Prelim_Skills_Exam_Question_31_CPE_018_CPE31S2_(Hare%2C_Andrei_Angelo_D_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Open the uploaded file in Question 31 Links to an external site.
#
# 2. Write a Python script using OpenCV that:
#
#     Reads an image named "nature.jpg"
#
#     Converts it to grayscale
#
#     Resizes it to 300x300 pixels
#
#     Saves the result as "processed.jpg"

# %%
#read an image
import cv2
img=cv2.imread("/content/drive/MyDrive/CPE 018-CPE31S2 - Emerging Technologies 1 in CpE/nature.jpg",1)
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
#converts it to grayscale
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

from google.colab.patches import cv2_imshow
cv2_imshow(img_gray)

# Resizes it to 300x300 pixels
resized = cv2.resize(img, (300, 300))
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %%
# Saves the result as "processed.jpg"
cv2.imwrite("processed.jpg",img_resize)
# Out:
# True
